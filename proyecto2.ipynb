# %% [markdown]
# ## Automatizar la buqueda de los datos de la accion
# * bibliotecas a intalar y expoortar para el proceso
#
#     ! pip install yfinance: para optener datos de yahoo finance, un gestor de bolsa de valores
#
#     ! pip install matplotlib: crea graficos y visualisaciones

# %%
! pip install yfinance
# Out:
# ...
#      ---------------------------------------- 0.0/3.0 MB ? eta -:--:--
#      ---------------------------------------- 0.0/3.0 MB ? eta -:--:--
#      --- ------------------------------------ 0.3/3.0 MB ? eta -:--:--
#      ------ --------------------------------- 0.5/3.0 MB 816.7 kB/s eta 0:00:04
#      ---------- ----------------------------- 0.8/3.0 MB 940.0 kB/s eta 0:00:03
#      ---------- ----------------------------- 0.8/3.0 MB 940.0 kB/s eta 0:00:03
#      ------------- -------------------------- 1.0/3.0 MB 941.5 kB/s eta 0:00:03
#      ------------- -------------------------- 1.0/3.0 MB 941.5 kB/s eta 0:00:03
#      ----------------- ---------------------- 1.3/3.0 MB 777.7 kB/s eta 0:00:03
#      -------------------- ------------------- 1.6/3.0 MB 813.0 kB/s eta 0:00:02
#      ------------------------ --------------- 1.8/3.0 MB 856.0 kB/s eta 0:00:02
#      ------------------------ --------------- 1.8/3.0 MB 856.0 kB/s eta 0:00:02
# ...

# %%
! pip install matplotlib
# Out:
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.1 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.1 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/8.1 MB 507.7 kB/s eta 0:00:15
#    -- ------------------------------------- 0.5/8.1 MB 507.7 kB/s eta 0:00:15
#    -- ------------------------------------- 0.5/8.1 MB 507.7 kB/s eta 0:00:15
#    -- ------------------------------------- 0.5/8.1 MB 507.7 kB/s eta 0:00:15
#    -- ------------------------------------- 0.5/8.1 MB 507.7 kB/s eta 0:00:15
#    --- ------------------------------------ 0.8/8.1 MB 361.0 kB/s eta 0:00:21
#    ----- ---------------------------------- 1.0/8.1 MB 440.4 kB/s eta 0:00:16
# ...

# %%
# importamos 
import yfinance as yf

# %%
# traemos datos de muestra

data = yf.Ticker("AAPL").history("6mo")

# %%
data.Close
# Out:
# Date
# 2024-11-18 00:00:00-05:00    227.471283
# 2024-11-19 00:00:00-05:00    227.730652
# 2024-11-20 00:00:00-05:00    228.448914
# 2024-11-21 00:00:00-05:00    227.970078
# 2024-11-22 00:00:00-05:00    229.316818
#                                 ...
# 2025-05-12 00:00:00-04:00    210.789993
# 2025-05-13 00:00:00-04:00    212.929993
# 2025-05-14 00:00:00-04:00    212.330002
# 2025-05-15 00:00:00-04:00    211.449997
# 2025-05-16 00:00:00-04:00    211.259995
# Name: Close, Length: 123, dtype: float64

# %%
# Utilizamos lo que viene siendo las columnas y su indice que es la fecha 
# y utilizamos la otra biblioteca matplotlib
cierre = data.Close
cierre.plot() #trae una grafica entre la fecha(x) y el cierre(y)
# Out:
# <Axes: xlabel='Date'>

# %%
# automatizando el Ticker de cada empresa para el usuario
tiker = input("Digita el Ticker de las acciones a visualisar: ")

data = yf.Ticker(tiker).history("6mo")
cierre.plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ## Se crean los analicis solicitados, referente a las busquedas de las acciones

# %%
# dato maximo de la columna cierre
round(cierre.max(), 2)
# Out:
# np.float64(258.4)

# %%
# dato minimo de la columna cierre
round(cierre.min(), 2)
# Out:
# np.float64(172.19)

# %%
# dato promedio de la columna cierre
round(cierre.mean(), 2)
# Out:
# np.float64(225.49)

# %%
# Se hace la buena practica, lo que se puede almacenar en una variable se hace

maximo = round(cierre.max(), 2)
minimo = round(cierre.min(), 2)
promedio = round(cierre.mean(), 2)
print(maximo, minimo, promedio, sep='\n') #el sep determina como se separan las impresiones
# Out:
# 258.4
# 172.19
# 225.49

# %% [markdown]
# ## Enviar E-mail automaticamente
#
# se utilizaran otras bibliotecas para este proceso
#
# ! pip install pyautogui: Biblioteca que permite manejar el maus y el teclado de forma automatica
#
# ! pip install pyperclip: Permite copiar y pergar informacion textual desde... hacia el porta papeles

# %%
! pip install pyautogui
# Out:
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
# ...

# %%
! pip install pyperclip
# Out:
# ...
# [notice] A new release of pip is available: 24.3.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pyautogui
import pyperclip
import webbrowser
import time

para = "estebanjimenez@unicomfacauca.edu.co"
asunto = "Analicis de acciones ultimos 6 meses"
cuerpo = f"""
Hola Esteban espero te encuentres bien, en este correo
se te enviara el analicis de los ultimos 6 meses de 
las finansas para la empresa de {tiker}:

Cotizacion max: USD {maximo}
Cotizacion min: USD {minimo}
Cotizacion media: USD {promedio}

quedo atento a cualquier inquietud 

PD: Stig J-C

""" 
# f string para utilizar las cadenas de texto con forma mas dinamica insertando calculos y bariables 
# f "xxxxxxxxxx {y lo que va}" se le dice formateo de texto

webbrowser.open("https://mail.google.com/mail/u/0/#inbox")

time.sleep(3)

pyautogui.PAUSE = 2 # es una pausa entre comandos que puedan requerir un tiempo de carga}

# se utiliza ahora pytogui para indicar el click

pyautogui.click(117, 297)   

pyperclip.copy(para) # como habia dicho antes, la biblioteca ayuda a copiar informacion y tenerla en el
                     # porta papeles para despues utilizarla 
pyautogui.hotkey("ctrl", "v") # aqui utilizamos los comandos de copiar y pegar

pyautogui.hotkey("tab")

pyperclip.copy(asunto)
pyautogui.hotkey("ctrl", "v")

pyautogui.hotkey("tab")

pyperclip.copy(cuerpo)
pyautogui.hotkey("ctrl", "v")

pyautogui.click(1105, 969)
pyautogui.hotkey("ctrl", "f4")

# %%
# se indicara atraves de cordenadas donde se dara el click automatico

time.sleep(4) 

pyautogui.position() #calcula las cordenadas para poder hubicar el maus en alguna funcion que necesitemos q haga clik
# Out:
# Point(x=1105, y=969)
